# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
URL='https://www.amazon.in/MEMAT-Rules-Make-Printed-T-Shirt/dp/B0GLPXFVZ2/ref=sr_1_1_sspa?crid=ZAMBM684F2X4&dib=eyJ2IjoiMSJ9.2-1eqendOe3aZMaIe6-w6s0LMPwY94NLAUPGdHkslfsDa3Qm3chwqVzx0qukvTymxGiTCRSP132tOwhc8Rm1JNids_pyLBBsodpoQ4zAKByv7jF7TMvdgsKWgSOYfeaHS-qnvyq3oJEOZOP58oNWnlCjbBOLk8-RsQeSv_i6zWQ6698ttP3ZKzTz3w3KHbwt76fYYL3nlyF9cZP-i25qFOq4-lf3FbGMqQEYt8_jvD0xZ7kdduDVB5btby5S7jS4mbRUUgaue2AD6ocJFExb-JJNlzbbZ3NOhniJDb4jLLw.-JZiUDXY23rnu5_vyqmQXXR2zUorW7VZehBDa-vRw6k&dib_tag=se&keywords=data%2Banalysy%2Btshirt&qid=1775451149&sprefix=data%2Banalysy%2Btshirt%2Caps%2C402&sr=8-1-spons&aref=1AlavmBsrK&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
page=requests.get(URL,headers=headers)

# %%
soup1=BeautifulSoup(page.content, 'html.parser')

soup2=BeautifulSoup(soup1.prettify(),'html.parser')
# print(soup2)

title=soup2.find(id='productTitle').getText()

price=soup2.find("span",class_="a-price-whole").getText()




print(title)
print(price)
# Out:
#                  Premium Graphic Printed T-Shirt - Unisex Streetwear Cotton Lycra - Front & Back Design, Round Neck, Regular Fit
#
#
#                    349

# %%
# Clean up the data a little bit

price=price.strip()
title=title.strip()
print(title)
print(price)
# Out:
# Premium Graphic Printed T-Shirt - Unisex Streetwear Cotton Lycra - Front & Back Design, Round Neck, Regular Fit
# 349

# %%
import datetime

today=datetime.date.today()

print(today)
# Out:
# 2026-04-06

# %%
import csv
header=['Title','Price','Date']
data=[title,price,today]

with open('AmazonwebScraperDataset.csv','w',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\dhanu\AmazonwebScraperDataset.csv")

# %%
print(df)
# Out:
#                                                 Title  Price        Date
# 0   Premium Graphic Printed T-Shirt - Unisex Stree...    349  2026-04-06
# 1   Premium Graphic Printed T-Shirt - Unisex Stree...    349  2026-04-06
# 2   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 3   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 4   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 5   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 6   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 7   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 8   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 9   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 10  Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 11  Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06

# %%
#Now we are appending data to the csv
with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL='https://www.amazon.in/MEMAT-Rules-Make-Printed-T-Shirt/dp/B0GLPXFVZ2/ref=sr_1_1_sspa?crid=ZAMBM684F2X4&dib=eyJ2IjoiMSJ9.2-1eqendOe3aZMaIe6-w6s0LMPwY94NLAUPGdHkslfsDa3Qm3chwqVzx0qukvTymxGiTCRSP132tOwhc8Rm1JNids_pyLBBsodpoQ4zAKByv7jF7TMvdgsKWgSOYfeaHS-qnvyq3oJEOZOP58oNWnlCjbBOLk8-RsQeSv_i6zWQ6698ttP3ZKzTz3w3KHbwt76fYYL3nlyF9cZP-i25qFOq4-lf3FbGMqQEYt8_jvD0xZ7kdduDVB5btby5S7jS4mbRUUgaue2AD6ocJFExb-JJNlzbbZ3NOhniJDb4jLLw.-JZiUDXY23rnu5_vyqmQXXR2zUorW7VZehBDa-vRw6k&dib_tag=se&keywords=data%2Banalysy%2Btshirt&qid=1775451149&sprefix=data%2Banalysy%2Btshirt%2Caps%2C402&sr=8-1-spons&aref=1AlavmBsrK&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    soup1=BeautifulSoup(page.content, 'html.parser')
    soup2=BeautifulSoup(soup1.prettify(),'html.parser')
# print(soup2)
    title=soup2.find(id='productTitle').getText()
    price=soup2.find("span",class_="a-price-whole").getText()
    price = price.strip()[1:]
    title = title.strip()
    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(86400) #Updates every day

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\dhanu\AmazonwebScraperDataset.csv")

# %%
print(df)
# Out:
#                                                 Title  Price        Date
# 0   Premium Graphic Printed T-Shirt - Unisex Stree...    349  2026-04-06
# 1   Premium Graphic Printed T-Shirt - Unisex Stree...    349  2026-04-06
# 2   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 3   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 4   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 5   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 6   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 7   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 8   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 9   Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 10  Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
# 11  Premium Graphic Printed T-Shirt - Unisex Stree...     49  2026-04-06
